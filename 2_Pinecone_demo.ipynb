# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingstonTardzenyuy/Generative-AI/blob/main/2_Pinecone_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install All the Required Packages

# %%
# !pip install langchain
# !pip install pinecone-client   # Helps us connect to pinecone-client
# !pip install pypdf   # to load pdf

# %%
# !pip install openai
# !pip install tiktoken

# %% [markdown]
# ## Importing Required Libraries

# %%
# !pip install -U langchain-community

# !pip install -U langchain langchain-community langchain-openai langchain-pinecone
# !pip install openai pinecone-client pypdf tiktoken

# %%
# !pip install -U langchain

# %%
# !pip install langchain-openai

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai langchain-pinecone
# Out:
# Found existing installation: langchain 1.0.5
# Uninstalling langchain-1.0.5:
#   Successfully uninstalled langchain-1.0.5
# Found existing installation: langchain-core 1.0.4
# Uninstalling langchain-core-1.0.4:
#   Successfully uninstalled langchain-core-1.0.4
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langchain-openai 1.0.2
# Uninstalling langchain-openai-1.0.2:
#   Successfully uninstalled langchain-openai-1.0.2
# Found existing installation: langchain-pinecone 0.2.13
# Uninstalling langchain-pinecone-0.2.13:
#   Successfully uninstalled langchain-pinecone-0.2.13

# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai langchain-pinecone


# !pip show langchain
# Out:
# ...
#   Using cached langchain-1.0.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langchain_core-1.0.4-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_openai-1.0.2-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached langchain_pinecone-0.2.13-py3-none-any.whl.metadata (8.6 kB)
# ...
# Using cached langchain-1.0.5-py3-none-any.whl (93 kB)
# Using cached langchain_core-1.0.4-py3-none-any.whl (471 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_openai-1.0.2-py3-none-any.whl (81 kB)
# Using cached langchain_pinecone-0.2.13-py3-none-any.whl (26 kB)
# ...
# Name: langchain
# Version: 1.0.5
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai langchain-pinecone

# %%
# !pip show langchain langchain-community
# Out:
# Name: langchain
# Version: 1.0.5
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# ---
# Name: langchain-community
# Version: 0.4.1
# Summary: Community contributed LangChain integrations.
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: aiohttp, dataclasses-json, httpx-sse, langchain-classic, langchain-core, langsmith, numpy, pydantic-settings, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.0.5
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai langchain-pinecone langchain-text-splitters langchain-chains
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement langchain-chains (from versions: none)
# ERROR: No matching distribution found for langchain-chains

# %%
# !pip install -U langchain langchain-core langchain-community \
               langchain-openai langchain-pinecone \
               langchain-text-splitters langchain-chains
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement langchain-chains (from versions: none)
# ERROR: No matching distribution found for langchain-chains

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai langchain-pinecone
# !pip install -U langchain langchain-core langchain-community langchain-openai langchain-pinecone
# Out:
# Found existing installation: langchain 1.0.5
# Uninstalling langchain-1.0.5:
#   Successfully uninstalled langchain-1.0.5
# Found existing installation: langchain-core 1.0.4
# Uninstalling langchain-core-1.0.4:
#   Successfully uninstalled langchain-core-1.0.4
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langchain-openai 1.0.2
# Uninstalling langchain-openai-1.0.2:
#   Successfully uninstalled langchain-openai-1.0.2
# Found existing installation: langchain-pinecone 0.2.13
# Uninstalling langchain-pinecone-0.2.13:
#   Successfully uninstalled langchain-pinecone-0.2.13
# ...
#   Using cached langchain-1.0.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langchain_core-1.0.4-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...

# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai langchain-pinecone langchain-text-splitters

# %%
# !pip install -U langchain langchain-core langchain-community \
               langchain-openai langchain-pinecone \
               langchain-text-splitters

# %%
# !pip install -U langchain-retrievers
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain-retrievers (from versions: none)
# ERROR: No matching distribution found for langchain-retrievers

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.0.5
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_openai import OpenAI
from langchain_pinecone import Pinecone
from langchain_classic.chains import RetrievalQA     # QA ontop of our data.
from langchain_core.prompts import PromptTemplate    # To allow us give custom prompts.
import os
