# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingstonTardzenyuy/Generative-AI/blob/main/Langhchain_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain==0.2.10
# !pip install langchain-openai==0.1.17
# !pip install python-dotenv==1.0.1
# !pip install langchain-groq==0.1.6
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.0/990.0 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 71.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.4.42
#     Uninstalling langsmith-0.4.42:
#       Successfully uninstalled langsmith-0.4.42
# ...

# %%
from google.colab import userdata
import os

# Access the OpenAI API key from Colab Secrets
openai_api_key = userdata.get("OPENAI_API_KEY")

if openai_api_key:
    print("OpenAI API key loaded successfully from Colab Secrets.")
else:
    print("OpenAI API key not found in Colab Secrets. Please add it using the '🔑 Secrets' icon on the left sidebar.")
# Out:
# OpenAI API key loaded successfully from Colab Secrets.

# %%
# Completion model.
from langchain_openai import OpenAI

llmModel = OpenAI(openai_api_key=openai_api_key)

# %%
response = llmModel.invoke("What is happening in Cameroon of recent ?")
print(response)
# Out:
# There have been several significant events and developments in Cameroon in recent times. These include:
#
# 1. Political instability and conflict: Cameroon has been facing a political crisis since 2016, when Anglophone separatists in the Northwest and Southwest regions declared independence from the French-speaking majority government. This has resulted in ongoing violence and clashes between government forces and separatist groups, causing displacement and human rights abuses.
#
# 2. Presidential election: In October 2018, incumbent President Paul Biya, who has been in power for 37 years, was re-elected for a seventh term in a controversial election marred by allegations of fraud and voter intimidation.
#
# ...

# %%
# Initializing the temp parameter.
creativeModel = OpenAI(
    openai_api_key=openai_api_key,
    temperature=0.9
)
response = creativeModel.invoke("What is happening in Cameroon of recent ?")
print(response)
# Out:
# 1. Anglophone Crisis: Cameroon has been facing a political and social crisis since 2016, known as the Anglophone Crisis. It began as a peaceful protest by English-speaking lawyers and teachers against the marginalization and discrimination they faced in a predominantly French-speaking country. However, it has since escalated into an armed conflict between separatist groups and government forces, resulting in thousands of deaths and displacement of over 500,000 people.
#
# 2. Political Tensions: The country witnessed a controversial presidential election in 2018, which was marred by accusations of fraud and lacked credibility. Incumbent President Paul Biya, who has been in power since 1982, was declared the winner for a seventh term, leading opposition parties to dispute the results and call for a recount. This has further deepened the political tensions and divisions in the country.
#
# ...

# %%
# Streaming.
for chunk in creativeModel.stream("Why do parrots have colorful feathers?"):
    print(chunk, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| as| a| result| of| natural| selection|.| The| bright| colors| and| patterns| serve| as| an| advantage| in| attracting| mates| and| communicating| with| other| par|rots|.| They| also| act| as| camouflage| in| their| natural| habitats|,| making| it| easier| for| them| to blend in| and avoid predators|.| Additionally|,| par|rots| are| social| animals| and| the| bright| colors| help| them| stand out| and| be| easily| recognized| within| their| flock|.| The vibrant colors| also| play| a role in| their| courtship displays|,| helping| them| attract| a| mate| and| establish| dominance| within| their| group.||

# %% [markdown]
# ## Chat Model

# %%
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(
    model = "gpt-3.5-turbo",
    openai_api_key=openai_api_key
)

# %%
messages = [
    {"role": "system", "content": "You are a helpful historian expert"},
    {"role": "user", "content": "How did Bamenda became a city ?"}
]

response = chatModel(messages)
print(response.content)
# Out:
# /tmp/ipython-input-2064036864.py:6: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   response = chatModel(messages)
# Bamenda is the capital city of the Northwest Region of Cameroon. The city's growth and development into a significant urban center can be attributed to a combination of historical, economic, and political factors.
#
# One key factor in Bamenda's development was its strategic location as a trading center in the region. The city's position along trade routes facilitated commerce and economic activity, leading to its growth and urbanization over time.
#
# Additionally, Bamenda's status as a regional administrative and political hub also played a role in its development as a city. As the capital of the Northwest Region, Bamenda became a center for government offices, services, and institutions, further bolstering its urban character.
#
# ...

# %% [markdown]
# ## Alternative AI

# %%
from google.colab import userdata
GROK_api = userdata.get('GROK_api')

# %%
from langchain_groq import ChatGroq

llamaChatModel = ChatGroq(
    model = "openai/gpt-oss-20b",
    groq_api_key=GROK_api
)

# %%
# Passing the system prompt
messages = [
    {"role": "system", "content": "You are a helpful historian expert"},
    {"role": "user", "content": "How did Bamenda became a city ?"}
]


# Invoking the model.
llamaResponse = llamaChatModel.invoke(messages)
print(llamaResponse.content)
# Out:
# **Bamenda’s rise from a small Bamileke settlement to a modern city**
# *(Cameroon – present‑day capital of the Northwest Region)*
#
# | Period | Key Events & Drivers | Resulting Impact on Bamenda |
# |--------|----------------------|-----------------------------|
# | **Pre‑colonial (before 19th c.)** | • Indigenous Bamileke (Bamenda people) settled the high‑altitude plateau (≈ 1,300 m). <br>• The area was a trade crossroads for local subsistence farmers and hunters. | • Bamenda existed as a cluster of villages (e.g., *Bamenda*, *Bamenda‑Bamenda*, *Bamenda‑Bamenda‑Bamenda*). <br>• Local governance was clan‑based, with a *Nobility* (Bamileke chiefs) and a council of elders. |
# ...

# %% [markdown]
# # Completion Model

# %%
from langchain_openai import OpenAI

llmModel = OpenAI(openai_api_key=openai_api_key)

# %%
# Loading the chat completion model too.
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(
    model = "gpt-3.5-turbo-0125",
    openai_api_key=openai_api_key
)

# %% [markdown]
# ## Prompts and Prompt Templates

# %%
# the promptTemplate is for completion model.
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    "Tell me a {adjective} story about {topic}"
)

llmModelPrompt = prompt_template.format(
    adjective="funny",
    topic="cats"
)

response = llmModel.invoke(llmModelPrompt)
print(response)
# Out:
# One day, a group of cats decided to have a race to see who was the fastest. The contestants were a Siamese cat, a Persian cat, and a Scottish Fold cat.
#
# The Siamese cat was confident in his speed and boasted to the other cats, "I am the fastest cat in the world, I will surely win this race!"
#
# The Persian cat, known for her grace and elegance, simply purred and said, "We shall see about that."
#
# The Scottish Fold cat, who was known for being lazy and slow, was feeling a bit nervous about the race. But he didn't want to back down, so he said, "I may not be the fastest, but I have a secret weapon up my sleeve."
#
# The race began and the Siamese cat quickly took the lead. The Persian cat gracefully followed behind, while the Scottish Fold cat slowly trailed behind.
#
# Just when it seemed like the Siamese cat was going to win, the Scottish Fold cat pulled out a can of tuna from his pocket and opened it, causing all the cats to stop and run towards him.
#
# ...

# %%
# Creating for chat completion model.

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an {profession} expert on {topic}"),
        ("human", "Hello, Mr. {profession}, can you please answer a qustion"),
        ("ai", "Sure!"),
        ("human", "{user_input}")
    ]
)

messages = chat_prompt_template.format_messages(
    profession="historian",
    topic="Cameroon",
    user_input="How did Bamenda became a city ?"
)

response = chatModel.invoke(messages)
print(response.content)
# Out:
# Bamenda, located in the Northwest Region of Cameroon, has a history that dates back centuries. It was originally a small village inhabited by the Tikar people. The area gradually grew in importance due to its strategic location and fertile land.
#
# Bamenda became a city in the early 20th century during the colonial period when the Germans established a military post in the area. The Germans built roads and infrastructure, which helped to further develop the region. After World War I, Cameroon became a League of Nations mandate territory administered by the French and British.
#
# Under British administration, Bamenda continued to grow and develop, becoming an important commercial and administrative center in the region. The city expanded rapidly in the post-independence period, with an influx of people from surrounding areas seeking economic opportunities.
#
# ...

# %% [markdown]
# ## Few Shot Prompting

# %%
from langchain_core.prompts import FewShotChatMessagePromptTemplate

examples = [
    {"input": "hi!", "output": "!hola!"},
    {"input": "bye!", "output": "!adios!"}

]

example_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("ai", "{output}")
    ]
)

few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=examples
)

final_prompt = ChatPromptTemplate.from_messages(
    [
        ('system', 'You are an English-Spanish translator'),
        few_shot_prompt,
        ('human', '{input}')
    ]
)


response = chatModel.invoke(
    final_prompt.format_messages(
        input="My Names are Kongnyuy Livingston. Happy to see you"
    )
)
print(response.content)
# Out:
# ¡Mucho gusto, Kongnyuy Livingston! ¿En qué puedo ayudarte hoy?

# %% [markdown]
# ## Chains

# %%
parser = SimpleJsonOutputParser()
chain = final_prompt | chatModel | parser
response = chain.invoke(
    {
        'input': "My Names are Kongnyuy Livingston. Happy to see you"
    }
)

response.content
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_core/output_parsers/json.py in parse_result(self, result, partial)
#      83             try:
# ---> 84                 return parse_json_markdown(text)
#      85             except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/utils/json.py in parse_json_markdown(json_string, parser)
#     146             json_str = match.group(2)
# --> 147     return _parse_json(json_str, parser=parser)
#     148
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/utils/json.py in _parse_json(json_str, parser)
#     162     # Parse the JSON string into a Python dictionary
# --> 163     return parser(json_str)
#     164
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/utils/json.py in parse_partial_json(s, strict)
# ...

# %% [markdown]
# ## Output Parsers

# %%
from langchain_openai import OpenAI

llmModel = OpenAI(
    api_key=openai_api_key,
    # temperature=0.9
)

# %%
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(
    model = "gpt-3.5-turbo-0125",
    openai_api_key=openai_api_key
)

# %%
from langchain_core.prompts import PromptTemplate
from langchain.output_parsers.json import SimpleJsonOutputParser

json_prompt = PromptTemplate.from_template(
    "Return a JSON object with an 'answer' key that answers the following question: {question}"
)

json_parser = SimpleJsonOutputParser()

chain = json_prompt | chatModel | json_parser
# response

# %%
# invoke our model.
chain.invoke(
    {
        "question": "What is the capital of France?"
    }
)
# Out:
# {'answer': 'Paris'}

# %%
## Optional, you can use Pydantic to define a custom output format.

from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field

# %%
# Define out class with the desired output format.

class Joke(BaseModel):
  setup: str = Field(description="question to set up a joke")
  punchline: str = Field(description="answer to resolve the joke")
  event: str = Field(description= "The event that lead to the joke")

# %%
# Define the parser referring the Pydantic Object.
parser = JsonOutputParser(pydantic_object=Joke)


# add the parser format instructions in the prompt defination.
prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)


# Create a chain with the prompt and the parser.
chain = prompt | chatModel | parser

chain.invoke(
    {
        "query": "Tell me a joke"
    }
)
# Out:
# {'setup': "Why couldn't the bicycle find its way home?",
#  'punchline': 'Because it lost its bearings!',
#  'event': 'Bicycle getting lost'}
