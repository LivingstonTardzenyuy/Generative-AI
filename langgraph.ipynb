# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingstonTardzenyuy/Generative-AI/blob/main/langgraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
grokAI = userdata.get('GROK_api')
openAI = userdata.get('OPENAI_API_KEY')
tavily = userdata.get('tavily')

# %%
# !pip install langchain_openai
# !pip install --upgrade langchain-community
# !pip install langgraph
# Note: langchain_grok is not a recognized package, so we're skipping its installation.
# !pip install langchain_grok
# Out:
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.4.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.11.10)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.1.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.44)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.11.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 52.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.1 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.1 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.1 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 langchain-classic-1.0.0 langchain-community-0.4.1 langchain-text-splitters-1.0.0 marshmallow-3.26.1 mypy-extensions-1.1.0 requests-2.32.5 typing-inspect-0.9.0

# %%
from langchain_openai import ChatOpenAI

chatgpt_llm = ChatOpenAI(
    model = "gpt-3.5-turbo",
    openai_api_key = openAI
)

# %%
from langchain_community import ChatGrok

grok_llm = ChatGrok(
    model = "grok-1",
    grok_api_key = grokAI
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2286637784.py in <cell line: 0>()
# ----> 1 from langchain_community import ChatGrok
#       2
#       3 grok_llm = ChatGrok(
#       4     model = "grok-1",
#       5     grok_api_key = grokAI
#
# ImportError: cannot import name 'ChatGrok' from 'langchain_community' (/usr/local/lib/python3.12/dist-packages/langchain_community/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults(
    tavily_api_key = tavily,
    max_results = 2
)

search.invoke("what schools are in University of Bamenda  ?")
# Out:
# [{'title': 'University of Bamenda - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/University_of_Bamenda',
#   'content': 'The main campus of the University of Bamenda is in Bambili, a subdivision in Bamenda, Mezam Division, Northwest region of Cameroon. The village is along the Ring Road northeast of Bamenda. An Anglophone area, many schoolchildren are taught in English, and the use of Pidgin English is widespread. English and Pidgin play a significant role in community life, but the Mbeligi language still maintains its place as the heart language of most Bambili people. [...] The College of Technology\n The Higher Institute of Commerce and Management\n The Higher Institute of Transport and Logistics\n The Higher Teachers’ Training College of Bamenda in Bambili\n The Higher Technical Teachers’ Training College of Bamenda in Bambili\n National Higher Polytechnic Institute (NAHPI, School of Engineering) [...] 2. ^ "Higher Education: Pioneer Vice Chancellor of Cameroon\'s Bamenda University Takes Office". Cameroon Today News. Cameroon Today. 5 October 2011. Archived from the original on 18 November 2022. Retrieved 11 September 2018. For now, only the Higher Teachers Training College and the Higher Technical Teachers Training College, the two pioneer institutions of the Bamenda University are functional and government sources say, the other faculties and institutions will soon go operational.',
#   'score': 0.9997408},
#  {'title': 'Faculties In The University Of Bamenda [2025] - Project House',
#   'url': 'https://project-house.net/faculties-in-the-university-of-bamenda/',
#   'content': 'Official logo of the University of Bamenda: See Fig 1\n\nThe University of Bamenda was created in 2010 and is one of the last 8 newly created universities in Cameroon. Its been rank as the 7th best university in Cameroon and global ranking 10409th best university in the world according to 2020 global ranking statistics.\n\nThe University of Bamenda is made up of 6 faculties, 2 colleges, and 4 schools.\n\nRead More on Top 10 Best Universities in Cameroon\n\n# Faculties In The University Of Bamenda [...] Similar to other Faculties in The University Of Bamenda, the Faculty of Economics and Management Sciences is divided into the following departments:\n\n1. Department of Accountancy\n2. Department of Banking And Finance\n3. Department of Management\n4. Department of Economics\n5. Department of Marketing\n6. Department of Human Resource Management\n\n## #3. Faculty of Education [...] Well Known among other Faculties In The University Of Bamenda, The Higher Teacher Training College (HTTC) is divided into the following departments.',
#   'score': 0.9863631}]

# %%
tools = [search]

# %%
from langgraph.prebuilt import create_react_agent

agent_executor = create_react_agent(
    chatgpt_llm, tools
)
# Out:
# /tmp/ipython-input-2380564175.py:3: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(

# %%
from langchain_core.messages import HumanMessage

response = agent_executor.invoke(
    {
        "messages": [HumanMessage(
            content = "How was the university of bamenda created, can i enroll"
        )]
    }
)

response['messages']
# Out:
# [HumanMessage(content='How was the university of bamenda created, can i enroll', additional_kwargs={}, response_metadata={}, id='e20e839a-9340-4183-a20e-81706c9d4211'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 93, 'total_tokens': 118, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CfkgBAKKHvVcCYpld1XhM998ueInJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--07ab5caa-52cf-475d-b525-248bc156acdc-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'University of Bamenda creation and enrollment process'}, 'id': 'call_YdcgHSoSyIGjisZTVm8HEusF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 93, 'output_tokens': 25, 'total_tokens': 118, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='[{"title": "University of Bamenda - Wikipedia", "url": "https://en.wikipedia.org/wiki/University_of_Bamenda", "content": "## Admission\\n\\n[edit]\\n\\nAdmission into the higher institutes/university colleges in the University of Bamenda is done through competitive entrance exams which involve written and oral examination. Students into other faculties are required to follow a registration procedure which involves presentation of results and study of files.\\n\\nCandidates are required to have obtained at least two (2) subjects in one sitting or Baccalaureate or its Equivalence GCE Advance level examination. [...] The university opened in 2011 as the second English language university in Cameroon, the University of Buea having been the only one up until then. It began with the Higher Teachers Training College and the Higher Technical Teachers Training College as the only faculties.\\n\\n## Campus\\n\\n[edit] [...] | Motto | \\"Knowledge, Probity, Entrepreneurship\\" |\\n| Established | December 2010; 13 years ago |\\n| Vice-Chancellor | Theresia Nkuo-Akenji |\\n| Location | Bamenda , Cameroon |\\n| Campus | Bambili |\\n| Nickname | UBa |\\n| Website | ( |\\n\\nThe University of Bamenda (UBa) is an Anglophone university in Bamenda, NorthWestern Cameroon \\"Northwest Region (Cameroon)\\").\\n\\n## History\\n\\n[edit]", "score": 0.7065353}, {"title": "UBA-Online -Apply for admission into the university - 360School", "url": "https://www.360school.unibaonlinelearning.net/admission_programs", "content": "General University Admission Requirements. • GCE A/L in at least two (2) subjects obtained in one sitting or Baccalaureate or its Equivalence.", "score": 0.02206811}]', name='tavily_search_results_json', id='51b451e8-cd61-401f-bb9c-49d8bc367751', tool_call_id='call_YdcgHSoSyIGjisZTVm8HEusF', artifact={'query': 'University of Bamenda creation and enrollment process', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://en.wikipedia.org/wiki/University_of_Bamenda', 'title': 'University of Bamenda - Wikipedia', 'content': '## Admission\n\n[edit]\n\nAdmission into the higher institutes/university colleges in the University of Bamenda is done through competitive entrance exams which involve written and oral examination. Students into other faculties are required to follow a registration procedure which involves presentation of results and study of files.\n\nCandidates are required to have obtained at least two (2) subjects in one sitting or Baccalaureate or its Equivalence GCE Advance level examination. [...] The university opened in 2011 as the second English language university in Cameroon, the University of Buea having been the only one up until then. It began with the Higher Teachers Training College and the Higher Technical Teachers Training College as the only faculties.\n\n## Campus\n\n[edit] [...] | Motto | "Knowledge, Probity, Entrepreneurship" |\n| Established | December 2010; 13 years ago |\n| Vice-Chancellor | Theresia Nkuo-Akenji |\n| Location | Bamenda , Cameroon |\n| Campus | Bambili |\n| Nickname | UBa |\n| Website | ( |\n\nThe University of Bamenda (UBa) is an Anglophone university in Bamenda, NorthWestern Cameroon "Northwest Region (Cameroon)").\n\n## History\n\n[edit]', 'score': 0.7065353, 'raw_content': None}, {'url': 'https://www.360school.unibaonlinelearning.net/admission_programs', 'title': 'UBA-Online -Apply for admission into the university - 360School', 'content': 'General University Admission Requirements. • GCE A/L in at least two (2) subjects obtained in one sitting or Baccalaureate or its Equivalence.', 'score': 0.02206811, 'raw_content': None}], 'response_time': 1.62, 'request_id': '9e8b2c04-516e-489e-a51b-2186bb83a755'}),
#  AIMessage(content="The University of Bamenda was established in December 2010 as the second English language university in Cameroon, with the University of Buea being the only one prior to its creation. Initially, it started with the Higher Teachers Training College and the Higher Technical Teachers Training College as the only faculties. The admission process for higher institutes/university colleges in the University of Bamenda involves competitive entrance exams that include written and oral examinations. Students looking to enroll in other faculties need to follow a registration procedure, which includes presenting results and the study of files.\n\nTo enroll at the University of Bamenda, candidates are required to have obtained at least two subjects in one sitting in GCE A/L examination or Baccalaureate or its Equivalence. You can find more information about the enrollment process on the university's official website or by reaching out to their admissions department.\n\nFor further details, you can visit the [Wikipedia page](https://en.wikipedia.org/wiki/University_of_Bamenda) or the [University of Bamenda admission page](https://www.360school.unibaonlinelearning.net/admission_programs).", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 225, 'prompt_tokens': 531, 'total_tokens': 756, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CfkgE4K2aC3HOLpXZpmcybmS3GZVR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--72af379b-342b-4eb4-b52d-44d0b3c13d3b-0', usage_metadata={'input_tokens': 531, 'output_tokens': 225, 'total_tokens': 756, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
from langchain_core.messages import HumanMessage

response = agent_executor.invoke(
    {
        "messages": [HumanMessage(
            content = "What is Python"
        )]
    }
)

response['messages']
# Out:
# [HumanMessage(content='What is Python', additional_kwargs={}, response_metadata={}, id='81aa0dfc-e07a-446b-b438-2342a9d3c06e'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 84, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CfkiZgcTqD4pOAeTLLaQG4zBNBPie', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--b6134f71-14f9-4fdc-b580-84cac3119f4c-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Python'}, 'id': 'call_695mzelXWBpIY7yE1SI0n64b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 84, 'output_tokens': 18, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='[{"title": "The Python Tutorial — Python 3.14.0 documentation", "url": "https://docs.python.org/3/tutorial/index.html", "content": "Python is an easy to learn, powerful programming language. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Python’s elegant syntax and dynamic typing, together with its interpreted nature, make it an ideal language for scripting and rapid application development in many areas on most platforms.", "score": 0.99664956}, {"title": "Python For Beginners | Python.org", "url": "https://www.python.org/about/gettingstarted/", "content": "If you want to know whether a particular application, or a library with particular functionality, is available in Python there are a number of possible sources of information. The Python web site provides a Python Package Index (also known as the Cheese Shop, a reference to the Monty Python script of that name). There is also a search page for a number of sources of Python-related information. Failing that, just Google for a phrase including the word \'\'python\'\' and you may well get the result", "score": 0.97462875}]', name='tavily_search_results_json', id='915d9178-e9c4-4cf3-a886-7389cc20415a', tool_call_id='call_695mzelXWBpIY7yE1SI0n64b', artifact={'query': 'Python', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://docs.python.org/3/tutorial/index.html', 'title': 'The Python Tutorial — Python 3.14.0 documentation', 'content': 'Python is an easy to learn, powerful programming language. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Python’s elegant syntax and dynamic typing, together with its interpreted nature, make it an ideal language for scripting and rapid application development in many areas on most platforms.', 'score': 0.99664956, 'raw_content': None}, {'url': 'https://www.python.org/about/gettingstarted/', 'title': 'Python For Beginners | Python.org', 'content': "If you want to know whether a particular application, or a library with particular functionality, is available in Python there are a number of possible sources of information. The Python web site provides a Python Package Index (also known as the Cheese Shop, a reference to the Monty Python script of that name). There is also a search page for a number of sources of Python-related information. Failing that, just Google for a phrase including the word ''python'' and you may well get the result", 'score': 0.97462875, 'raw_content': None}], 'response_time': 0.94, 'request_id': '6217de9b-30d9-4742-85f2-2826bad9de17'}),
#  AIMessage(content='Python is an easy to learn, powerful programming language. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Python’s elegant syntax and dynamic typing, together with its interpreted nature, make it an ideal language for scripting and rapid application development in many areas on most platforms.\n\nIf you want to know more about Python, you can visit [The Python Tutorial](https://docs.python.org/3/tutorial/index.html) or check out [Python For Beginners on Python.org](https://www.python.org/about/gettingstarted/).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 360, 'total_tokens': 472, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CfkibJ2A4YzmJdQBRwk3zhc6DiGb0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--33ca84d8-f4e8-4bb7-b03a-a82e9cc82164-0', usage_metadata={'input_tokens': 360, 'output_tokens': 112, 'total_tokens': 472, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="when will the graduation of the University of bamenda ")]}
):

  print(chunk)
  print("-----")
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 92, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CfklwyfsI9anY4ldmPeHD2Lo99ES0', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--b360a5b7-19cb-4568-8496-b3b50a4e54bb-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'University of Bamenda graduation date'}, 'id': 'call_50W2KOE3lnYy3RCRZgCidC42', 'type': 'tool_call'}], usage_metadata={'input_tokens': 92, 'output_tokens': 23, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# -----
# {'tools': {'messages': [ToolMessage(content='[{"title": "The University of Bamenda", "url": "https://uniba.cm/", "content": "Description of the Programme: Students must earn a minimum of 180 credits including credits from elective courses.\\n\\n Duration\\n\\n  3 year(s)\\n\\n#### Professional Masters in Environmental Science (3 Options)\\n\\nDescription of the Programme: Students must earn a total number of credits between 120-128 required for graduation OPTIONS: - Natural Environmental Resource Management, - Industrial and Urban Waste Management, - Occupational Health and Safety Management.\\n\\n Duration\\n\\n  2 year(s) [...] #### M.Sc. in Geoscience (5 Options)\\n\\nDescription of the Programme: Students must earn a total number of credits of between 120 required for graduation. OPTIONS: a. Economic Geology and Mineral Exploration, b. Petroleum Geoscience, c. Micropaleontology/Biostratigraphy, d. Hydrogeology. e. Petrology and Geochemistry\\n\\n Duration\\n\\n  2 year(s)\\n\\n#### Ph.D. in Applied Geology (2 Options) [...] UBa Student\\n Admin login\\n\\n### Welcome to\\n\\n# The University Of Bamenda\\n\\nThe Unviversity of the Future\\n\\nTop stories\\n\\n## Campus News\\n\\n May 08, 2025\\n\\n#### The University of Bamenda signed Memoranda of Understanding and Specific Partnership Agreements with 22 Private Higher Institutions of Learning in Cameroon.\\n\\nThe University of Bamenda signed Memoranda of Understanding and Specific Partnership Agreements with 22 Private Higher Institutions of Learning in Cameroon.\\n\\n Read More\\n\\n Apr 26, 2025", "score": 0.5299209}, {"title": "CONVOCATION CEREMONY RESCHEDULED The graduation ...", "url": "https://www.facebook.com/100063765364817/posts/convocation-ceremony-rescheduledthe-graduation-ceremony-for-the-20242025-batch-h/1413450157457150/", "content": "CONVOCATION CEREMONY RESCHEDULED The graduation ceremony for the 2024/2025 batch has been rescheduled to January 16th, 2026.", "score": 0.17668614}]', name='tavily_search_results_json', id='582b2405-dfb2-46ff-acc7-0b62fb48e085', tool_call_id='call_50W2KOE3lnYy3RCRZgCidC42', artifact={'query': 'University of Bamenda graduation date', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://uniba.cm/', 'title': 'The University of Bamenda', 'content': 'Description of the Programme: Students must earn a minimum of 180 credits including credits from elective courses.\n\n Duration\n\n  3 year(s)\n\n#### Professional Masters in Environmental Science (3 Options)\n\nDescription of the Programme: Students must earn a total number of credits between 120-128 required for graduation OPTIONS: - Natural Environmental Resource Management, - Industrial and Urban Waste Management, - Occupational Health and Safety Management.\n\n Duration\n\n  2 year(s) [...] #### M.Sc. in Geoscience (5 Options)\n\nDescription of the Programme: Students must earn a total number of credits of between 120 required for graduation. OPTIONS: a. Economic Geology and Mineral Exploration, b. Petroleum Geoscience, c. Micropaleontology/Biostratigraphy, d. Hydrogeology. e. Petrology and Geochemistry\n\n Duration\n\n  2 year(s)\n\n#### Ph.D. in Applied Geology (2 Options) [...] UBa Student\n Admin login\n\n### Welcome to\n\n# The University Of Bamenda\n\nThe Unviversity of the Future\n\nTop stories\n\n## Campus News\n\n May 08, 2025\n\n#### The University of Bamenda signed Memoranda of Understanding and Specific Partnership Agreements with 22 Private Higher Institutions of Learning in Cameroon.\n\nThe University of Bamenda signed Memoranda of Understanding and Specific Partnership Agreements with 22 Private Higher Institutions of Learning in Cameroon.\n\n Read More\n\n Apr 26, 2025', 'score': 0.5299209, 'raw_content': None}, {'url': 'https://www.facebook.com/100063765364817/posts/convocation-ceremony-rescheduledthe-graduation-ceremony-for-the-20242025-batch-h/1413450157457150/', 'title': 'CONVOCATION CEREMONY RESCHEDULED The graduation ...', 'c ...
# -----
# {'agent': {'messages': [AIMessage(content='The graduation ceremony for the University of Bamenda for the 2024/2025 batch has been rescheduled to January 16th, 2026. You can find more information on the [University of Bamenda website](https://uniba.cm/).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 601, 'total_tokens': 655, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Cfklz2iQPiDZpaqvQ0SrjcDvYLvrt', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--b007babd-5cda-43f3-8c8f-4ea051bdf874-0', usage_metadata={'input_tokens': 601, 'output_tokens': 54, 'total_tokens': 655, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# -----

# %% [markdown]
# ## Adding Memory
#
# Adding  memory in LangGraph is very similar to in Langchain

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()
agent_executor = create_react_agent(llm, tools, checkpointer=memory)

config = {
    "configurable": {"thread_id": "001"}
}
# Out:
# /tmp/ipython-input-1955646184.py:4: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(llm, tools, checkpointer=memory)

# %%
for chunk in agent_exucutor.stream(
    {"messages": [HumanMessage(content="Who won the 2024 soccer Europa")]}, config
):
print(chunk)
print('-----')
