# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingstonTardzenyuy/Generative-AI/blob/main/LCEL_little_more.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
openAI = userdata.get('OPENAI_API_KEY')
grokAI = userdata.get('GROK_api')

# %%
# !pip install groq

import openai
from groq import Groq

# Initialize Groq client
grok_client = Groq(api_key=grokAI)

# Initialize OpenAI client
openai_client = openai.OpenAI(api_key=openAI)

print("Grok and OpenAI models initialized.")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.3/137.3 kB 5.4 MB/s eta 0:00:00
# ...
# Grok and OpenAI models initialized.

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_template(
    "tell me a curious fact about {succer_player}"
)

output_parser = StrOutputParser()

# %%
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 12.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.80
#     Uninstalling langchain-core-0.3.80:
#       Successfully uninstalled langchain-core-0.3.80
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.1.0 which is incompatible.
# ...

# %%
# !pip uninstall -y langchain langchain-groq langchain-core
# !pip install langchain-groq
# !pip install langchain_openai
# Out:
# Found existing installation: langchain 0.3.27
# Uninstalling langchain-0.3.27:
#   Successfully uninstalled langchain-0.3.27
# Found existing installation: langchain-groq 1.0.1
# Uninstalling langchain-groq-1.0.1:
#   Successfully uninstalled langchain-groq-1.0.1
# Found existing installation: langchain-core 1.1.0
# Uninstalling langchain-core-1.1.0:
#   Successfully uninstalled langchain-core-1.1.0
# ...
#   Using cached langchain_groq-1.0.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached langchain_core-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# ...
# Using cached langchain_groq-1.0.1-py3-none-any.whl (17 kB)
# Using cached langchain_core-1.1.0-py3-none-any.whl (473 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI

# llm = ChatGroq(temperature=0, groq_api_key=grokAI, model_name="mixtral-8x7b-32768") # You can choose a different model_name if needed
llm = ChatOpenAI(
    temperature=0.8,
    openai_api_key=openAI,
    model_name="gpt-3.5-turbo"
)
chain = prompt | llm | output_parser

chain.invoke(
    {"soccer_player": "Ronaldo"}
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-170872531.py in <cell line: 0>()
# ----> 1 from langchain_groq import ChatGroq
#       2 from langchain_openai import ChatOpenAI
#       3
#       4 # llm = ChatGroq(temperature=0, groq_api_key=grokAI, model_name="mixtral-8x7b-32768") # You can choose a different model_name if needed
#       5 llm = ChatOpenAI(
#
# /usr/local/lib/python3.12/dist-packages/langchain_groq/__init__.py in <module>
#       1 """Groq integration for LangChain."""
#       2
# ----> 3 from langchain_groq.chat_models import ChatGroq
#       4 from langchain_groq.version import __version__
#       5
#
# /usr/local/lib/python3.12/dist-packages/langchain_groq/chat_models.py in <module>
#      14 )
#      15 from langchain_core.language_models import LanguageModelInput
# ---> 16 from langchain_core.language_models.chat_models import (
# ...

# %%
historian_prompt = ChatPromptTemplate.from_template("Was {politician} a positive for Humanity")

composed_chain = {
    "politician":
} |historian_prompt | llm |StrOutputParser()

# %%
05:10
